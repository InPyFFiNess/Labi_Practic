# %%
import pandas as pd

# %%
df1 = pd.read_csv('var8.csv')
df1
# Out:
#       Участники гражданского оборота       Тип операции  Сумма операции  \
# 0                          физ. лицо  получение средств         2643.37
# 1                           юр. лицо  получение средств         4050.98
# 2                           юр. лицо  получение средств         4225.21
# 3                          физ. лицо  получение средств         1650.48
# 4                          физ. лицо  получение средств         3426.01
# ...                              ...                ...             ...
# 99995                       юр. лицо   списание средств          229.02
# 99996                      физ. лицо   списание средств          921.55
# 99997                      физ. лицо  получение средств          308.04
# 99998                       юр. лицо   списание средств          613.80
# 99999                      физ. лицо  получение средств          171.25
#
#        Вид расчета Место оплаты           Терминал оплаты Дата оплаты  \
# ...

# %%
df2 = df_unique = df1.drop_duplicates()
df2
# Out:
#       Участники гражданского оборота       Тип операции  Сумма операции  \
# 0                          физ. лицо  получение средств         2643.37
# 1                           юр. лицо  получение средств         4050.98
# 2                           юр. лицо  получение средств         4225.21
# 3                          физ. лицо  получение средств         1650.48
# 4                          физ. лицо  получение средств         3426.01
# ...                              ...                ...             ...
# 99991                       юр. лицо  получение средств         1837.20
# 99993                      физ. лицо  получение средств          203.85
# 99994                       юр. лицо  получение средств         4169.45
# 99997                      физ. лицо  получение средств          308.04
# 99999                      физ. лицо  получение средств          171.25
#
#        Вид расчета Место оплаты           Терминал оплаты Дата оплаты  \
# ...

# %%
cr = len(df1)-len(df2)
cr
# Out:
# 25438
